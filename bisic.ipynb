# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
filepath = pwd + "/simple_csv.csv"

# %%
first_import = pd.read_csv(filepath,nrows=10)
first_import
# Out:
#                                          movie_title content_rating  \
# 0  Percy Jackson & the Olympians: The Lightning T...             PG
# 1                                        Please Give              R
# 2                                                 10              R
# 3                    12 Angry Men (Twelve Angry Men)             NR
# 4                       20,000 Leagues Under The Sea              G
# 5                                        10,000 B.C.          PG-13
# 6                                       The 39 Steps             NR
# 7                                       3:10 to Yuma             NR
# 8                          Charly (A Heartbeat Away)             PG
# 9                                    Abraham Lincoln             NR
#
#                                               genres             directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...        Chris Columbus
# ...

# %%
first_import["actors"]
# Out:
# 0    Logan Lerman, Brandon T. Jackson, Alexandra Da...
# 1    Catherine Keener, Amanda Peet, Oliver Platt, R...
# 2    Dudley Moore, Bo Derek, Julie Andrews, Robert ...
# 3    Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# 4    James Mason, Kirk Douglas, Paul Lukas, Peter L...
# 5    Steven Strait, Camilla Belle, Cliff Curtis, Jo...
# 6    Robert Donat, Madeleine Carroll, Godfrey Tearl...
# 7    Glenn Ford, Van Heflin, Felicia Farr, Leora Da...
# 8    Heather Beers, Gary Neilson, Lisa McCammon, Ja...
# 9    Walter Huston, Una Merkel, Kay Hammond, Ian Ke...
# Name: actors, dtype: object

# %%
first_import["new_column"]=1
first_import["new_column2"]=list(range(10))
first_import["added output"]=first_import["new_column"]+first_import["new_column2"]
first_import
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12520/2605922602.py in <module>
#       1 first_import["new_column"]=1
# ----> 2 first_import["new_column2"]=list(range(10))
#       3 first_import["added output"]=first_import["new_column"]+first_import["new_column2"]
#       4 first_import
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ...

# %%
first_import.iloc[1000:1050, [0,9]]
# Out:
# Empty DataFrame
# Columns: [movie_title, production_company]
# Index: []

# %%
first_import = pd.read_csv(filepath)
first_import.iloc[17000]
# Out:
# movie_title                                                             Walk on Water
# content_rating                                                                      R
# genres                              Art House & International, Drama, Mystery & Su...
# directors                                                                   Eytan Fox
# authors                                                                  Gal Uchovsky
# actors                              Lior Ashkenazi, Knut Berger, Carolina Peters, ...
# original_release_date                                                      04/03/2005
# streaming_release_date                                                     09/12/2016
# runtime                                                                         102.0
# production_company                                               Roadside Attractions
# tomatometer_status                                                              Fresh
# ...

# %%
list(first_import.columns)
# Out:
# ['movie_title',
#  'content_rating',
#  'genres',
#  'directors',
#  'authors',
#  'actors',
#  'original_release_date',
#  'streaming_release_date',
#  'runtime',
#  'production_company',
#  'tomatometer_status',
#  'tomatometer_rating',
#  'tomatometer_count',
#  'audience_status',
#  'audience_rating',
#  'audience_count',
#  'tomatometer_top_critics_count',
#  'tomatometer_fresh_critics_count',
#  'tomatometer_rotten_critics_count']

# %%
first_import.describe()
# Out:
#             runtime  tomatometer_rating  tomatometer_count  audience_rating  \
# count  17398.000000        17668.000000       17668.000000     17416.000000
# mean     102.214048           60.884763          57.139801        60.554260
# std       18.702511           28.443348          68.370047        20.543369
# min        5.000000            0.000000           5.000000         0.000000
# 25%       90.000000           38.000000          12.000000        45.000000
# 50%       99.000000           67.000000          28.000000        63.000000
# 75%      111.000000           86.000000          75.000000        78.000000
# max      266.000000          100.000000         574.000000       100.000000
#
#        audience_count  tomatometer_top_critics_count  \
# count    1.741500e+04                   17712.000000
# mean     1.439401e+05                      14.586326
# std      1.763577e+06                      15.146349
# min      5.000000e+00                       0.000000
# ...

# %%
first_import.corr()
# Out:
#                                    runtime  tomatometer_rating  \
# runtime                           1.000000            0.089672
# tomatometer_rating                0.089672            1.000000
# tomatometer_count                 0.272304            0.083565
# audience_rating                   0.229088            0.654068
# audience_count                    0.062672            0.013408
# tomatometer_top_critics_count     0.243070            0.055090
# tomatometer_fresh_critics_count   0.267346            0.339090
# tomatometer_rotten_critics_count  0.149550           -0.400668
#
#                                   tomatometer_count  audience_rating  \
# runtime                                    0.272304         0.229088
# tomatometer_rating                         0.083565         0.654068
# tomatometer_count                          1.000000         0.147596
# audience_rating                            0.147596         1.000000
# ...

# %%
first_import["genres"].unique()
# Out:
# array(['Action & Adventure, Comedy, Drama, Science Fiction & Fantasy',
#        'Comedy', 'Comedy, Romance', ...,
#        'Animation, Art House & International, Drama, Science Fiction & Fantasy, Romance',
#        'Art House & International, Romance',
#        'Action & Adventure, Drama, Horror, Kids & Family, Mystery & Suspense'],
#       dtype=object)

# %%
first_import[first_import["genres"]=="Drama"]
# Out:
#                           movie_title content_rating genres  \
# 12                      The Lost City              R  Drama
# 13                 The Breaking Point             NR  Drama
# 55                              Dirty              R  Drama
# 58     All Quiet on the Western Front             NR  Drama
# 90                          Alexandra             NR  Drama
# ...                               ...            ...    ...
# 17655              Your Son (Tu Hijo)             NR  Drama
# 17657                  You're Not You              R  Drama
# 17674                        Zandalee              R  Drama
# 17684                Zero Dark Thirty              R  Drama
# 17687                 Zero Motivation             NR  Drama
#
#                 directors                                        authors  \
# 12            Andy Garcia  G. Cabrera Infante, Guillermo Cabrera Infante
# 13         Michael Curtiz                              Ranald MacDougall
# ...

# %%
first_import[(first_import["genres"]=="Comedy")|(first_import["actors"]=="Reilly Dolman")]
# Out:
#                 movie_title content_rating  genres  \
# 1               Please Give              R  Comedy
# 23                Bandwagon              R  Comedy
# 27     A Tale of Two Pizzas             PG  Comedy
# 29       Going the Distance              R  Comedy
# 53          When Do We Eat?              R  Comedy
# ...                     ...            ...     ...
# 17624    You, Me and Dupree          PG-13  Comedy
# 17636        Young Einstein             PG  Comedy
# 17651         Your Highness              R  Comedy
# 17683         Zero Charisma             NR  Comedy
# 17705           Zoolander 2          PG-13  Comedy
#
#                            directors  \
# 1                  Nicole Holofcener
# 23                      John Schultz
# 27                   Vincent Sassone
# 29                    Mark Griffiths
# 53                   Salvador Litvak
# ...                              ...
# 17624       Anthony Russo, Joe Russo
# 17636                  Yahoo Serious
# ...

# %%
first_import["computer_data"]=pd.to_datetime(first_import["original_release_date"])
first_import
# Out:
#                                              movie_title content_rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...             PG
# 1                                            Please Give              R
# 2                                                     10              R
# 3                        12 Angry Men (Twelve Angry Men)             NR
# 4                           20,000 Leagues Under The Sea              G
# ...                                                  ...            ...
# 17707                                          Zoot Suit              R
# 17708                                           Zootopia             PG
# 17709                                    Zorba the Greek             NR
# 17710                                               Zulu             PG
# 17711                                          Zulu Dawn             PG
#
#                                                   genres  \
# ...

# %%
first_import["computer_data"]
# Out:
# 0       2010-12-02
# 1       2010-04-30
# 2       1979-05-10
# 3       1957-04-13
# 4       1954-01-01
#            ...
# 17707   1981-02-10
# 17708   2016-04-03
# 17709   1964-12-17
# 17710   1964-06-17
# 17711   1979-12-14
# Name: computer_data, Length: 17712, dtype: datetime64[ns]

# %%
first_import["computer_data"].dropna()
# Out:
# 0       2010-12-02
# 1       2010-04-30
# 2       1979-05-10
# 3       1957-04-13
# 4       1954-01-01
#            ...
# 17707   1981-02-10
# 17708   2016-04-03
# 17709   1964-12-17
# 17710   1964-06-17
# 17711   1979-12-14
# Name: computer_data, Length: 16546, dtype: datetime64[ns]

# %%
from datetime import datetime as dt

# %%
first_import["computer_data"].fillna(dt(2010, 12,2),inplace=True)

# %%
first_import["unix_time"]=first_import["computer_data"].astype(str)
first_import
# Out:
#                                              movie_title content_rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...             PG
# 1                                            Please Give              R
# 2                                                     10              R
# 3                        12 Angry Men (Twelve Angry Men)             NR
# 4                           20,000 Leagues Under The Sea              G
# ...                                                  ...            ...
# 17707                                          Zoot Suit              R
# 17708                                           Zootopia             PG
# 17709                                    Zorba the Greek             NR
# 17710                                               Zulu             PG
# 17711                                          Zulu Dawn             PG
#
#                                                   genres  \
# ...

# %%
first_import.groupby("tomatometer_status")["movie_title"].count().reset_index().sort_values(by="movie_title", ascending=False)
# Out:
#   tomatometer_status  movie_title
# 2             Rotten         7565
# 1              Fresh         6844
# 0    Certified-Fresh         3259
