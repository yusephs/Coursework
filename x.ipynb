# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
filepath = pwd + "/data.csv"

# %%
first_import = pd.read_csv(filepath,nrows=10)
first_import
# Out:
#                                          movie_title  Unnamed: 1  \
# 0  Percy Jackson & the Olympians: The Lightning T...         NaN
# 1                                        Please Give         NaN
# 2                                                 10         NaN
# 3                    12 Angry Men (Twelve Angry Men)         NaN
# 4                       20,000 Leagues Under The Sea         NaN
# 5                                        10,000 B.C.         NaN
# 6                                       The 39 Steps         NaN
# 7                                       3:10 to Yuma         NaN
# 8                          Charly (A Heartbeat Away)         NaN
# 9                                    Abraham Lincoln         NaN
#
#   content_rating                                             genres  \
# 0             PG  Action & Adventure, Comedy, Drama, Science Fic...
# 1              R                                             Comedy
# ...
